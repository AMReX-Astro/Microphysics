# %% [markdown]
# # ECSN Burn Test

# %%
import BurnUtils
import numpy as np

# %%
probin_file = "probin_ecsn"

# %%
driver = BurnUtils.BurnerDriver(probin_file)

# %%
driver.list_species()
# Out:
# Species in network:
#
# hydrogen-1 (h1)
# helium-4 (he4)
# oxygen-16 (o16)
# oxygen-20 (o20)
# fluorine-20 (f20)
# neon-20 (ne20)
# magnesium-24 (mg24)
# aluminum-27 (al27)
# silicon-28 (si28)
# phosphorus-31 (p31)
# sulfur-32 (s32)

# %% [markdown]
# ## Test 1 from Josiah

# %%
driver.set_initial_density(7607783959.50421)

driver.set_initial_temperature(983559309.749412)

driver.set_initial_species("h1", 0.0)
driver.set_initial_species("he4", 1.14998095787427E-18)
driver.set_initial_species("o16", 0.5955320774)
driver.set_initial_species("o20", 0.203902681)
driver.set_initial_species("f20", 1.17278643621995E-07)
driver.set_initial_species("ne20", 0.19753136)
driver.set_initial_species("mg24", 0.0)
driver.set_initial_species("al27", 0.0)
driver.set_initial_species("si28", 0.0027259815)
driver.set_initial_species("p31", 0.0)
driver.set_initial_species("s32", 0.0)

# %%
driver.rhs(driver.initial_burn_state)

# %%
enuc = driver.get_enuc_dot(driver.initial_burn_state)
print("Energy generation rate (erg/g/s): {}".format(enuc))
print(driver.initial_burn_state)
# Out:
# Energy generation rate (erg/g/s): -572522256.6568681
# <burn_t>{
#     rho : 7607783959.50421,
#     t : 983559309.749412,
#     e : 2.490743133790312e+18,
#     xn : array([0.00000000e+00, 1.14998096e-18, 5.95532077e-01, 2.03902681e-01,
#        1.17278644e-07, 1.97531360e-01, 0.00000000e+00, 0.00000000e+00,
#        2.72598150e-03, 0.00000000e+00, 0.00000000e+00]),
#     cv : 14444247.553061701,
#     cp : 14486626.878325198,
#     y_e : 0.47945583462538965,
#     eta : 87.75746182063078,
#     cs : 1099451413.7881703,
#     dx : 1.3035428997061241e-76,
#     abar : 17.42469332287015,
#     zbar : 8.354370880208164,
#     t_old : 6.304588249174252e-34,
#     dcvdt : 3.5977897643913976e+179,
#     dcpdt : 1.3973698208408206e-76,
#     ydot : array([ 1.16695205e-11, -7.26850364e-12, -4.11345965e-11,  5.79382894e-11,
#         7.42255606e-12, -5.81959032e-11,  2.16734518e-12,  0.00000000e+00,
#         4.23112889e-12,  1.16695205e-11,  5.05156388e-16, -3.95207429e+01,
# ...

# %% [markdown]
# ## Test 2 from Josiah

# %%
driver.set_initial_density(8346403698.95185)

driver.set_initial_temperature(656536305.140964)

driver.set_initial_species("h1", 0.0)
driver.set_initial_species("he4", 8.89957317703129E-23)
driver.set_initial_species("o16", 0.5999942706)
driver.set_initial_species("o20", 0.3926652894)
driver.set_initial_species("f20", 0.000000002)
driver.set_initial_species("ne20", 0.0073364571)
driver.set_initial_species("mg24", 0.0)
driver.set_initial_species("al27", 0.0)
driver.set_initial_species("si28", 3.518236231242E-06)
driver.set_initial_species("p31", 0.0)
driver.set_initial_species("s32", 0.0)

# %%
driver.rhs(driver.initial_burn_state)

# %%
enuc = driver.get_enuc_dot(driver.initial_burn_state)
print("Energy generation rate (erg/g/s): {}".format(enuc))
print(driver.initial_burn_state)
# Out:
# Energy generation rate (erg/g/s): -16138922.581570987
# <burn_t>{
#     rho : 8346403698.95185,
#     t : 656536305.140964,
#     e : 2.4366503017450455e+18,
#     xn : array([0.00000000e+00, 8.89957318e-23, 5.99994271e-01, 3.92665289e-01,
#        2.00000000e-09, 7.33645710e-03, 0.00000000e+00, 0.00000000e+00,
#        3.51823623e-06, 0.00000000e+00, 0.00000000e+00]),
#     cv : 13444158.983137527,
#     cp : 13470518.44019436,
#     y_e : 0.46073323962811563,
#     eta : 133.98527882572262,
#     cs : 1086123519.6557314,
#     dx : 1.3035428997061241e-76,
#     abar : 17.391348207658748,
#     zbar : 8.012772201215236,
#     t_old : 6.304588249174252e-34,
#     dcvdt : 3.5977897643913976e+179,
#     dcpdt : 1.3973698208408206e-76,
#     ydot : array([ 3.75545872e-17, -2.13349498e-17, -1.35886276e-16,  1.24835159e-12,
#         1.35222972e-13, -1.38354101e-12,  5.60711361e-19,  0.00000000e+00,
#         1.33342876e-17,  3.75545872e-17,  4.90756421e-25, -1.19809216e+00,
# ...
